# %% [markdown]
# # K Nearest Neighbor

# %% [markdown]
# ### Detailed K-Nearest Neighbors (KNN)
#
#  1. **Core Concept**
#
# **K-Nearest Neighbors (KNN):**
#
# - **Type:** Supervised Learning algorithm.
# - **Purpose:** KNN is used for both classification and regression tasks:
#   - **Classification:** In classification tasks, KNN predicts the category (class) of a new data point based on the majority class among its K nearest neighbors in the feature space.
#   - **Regression:** In regression tasks, KNN predicts a continuous value based on the average (or weighted average) of the values of the K nearest neighbors.
# - **Nature:** Instance-based learning algorithm. This means KNN makes predictions by comparing the new data point to previously observed instances in the training set, without explicitly training a model or learning parameters. Instead, it stores the training data and makes predictions based on the proximity of new points to the stored instances.
#
#  2. **Methodology**
#
# **How KNN Works:**
#
# 1. **Choose K (Number of Neighbors):**
#    - The user selects the value of K, which determines how many neighbors will influence the prediction for a new data point.
#    - A common practice is to experiment with different values of K to optimize performance.
#
# 2. **Calculate Distance:**
#    - For each test point, the algorithm calculates the distance to every other point in the training set. The distance metric most commonly used is **Euclidean distance**, but other metrics like **Manhattan distance** or **Minkowski distance** can also be used depending on the problem.
#
# 3. **Find the K Nearest Neighbors:**
#    - Once the distances are calculated, KNN identifies the **K nearest neighbors** (the K points closest to the test point).
#
# 4. **Prediction:**
#    - **Classification:** The predicted class label is assigned by majority vote among the K nearest neighbors. For example, if 3 out of 5 neighbors belong to class A, the prediction will be class A.
#    - **Regression:** The predicted value is calculated as the average (or weighted average) of the target values of the K nearest neighbors.

# %% [markdown]
#  Methodology of K-Nearest Neighbors (KNN)
#
# The **K-Nearest Neighbors (KNN)** algorithm is a simple, instance-based learning algorithm used for classification and regression tasks. The methodology involves determining the K nearest data points to a query point and using those neighbors to make predictions. Below is a detailed step-by-step explanation of the methodology:
#
# ---
#
#  1. **Choose K (Number of Neighbors)**
#
# - **Definition:** The first step is to decide the value of **K**, which refers to the number of nearest neighbors to consider when making a prediction.
#
# - **How to choose K:**
#   - **Small K:** A small K (e.g., K = 1) may lead to noisy predictions because the model may be too sensitive to outliers.
#   - **Large K:** A large K (e.g., K = 15 or 20) helps to smooth out noise, but if K is too large, the model may underfit the data and fail to capture important patterns.
#   - **Cross-validation:** Typically, K is chosen through experimentation, often using cross-validation, to determine which value of K gives the best performance for the given dataset.
#
# ---
#
#  2. **Calculate Distance between the Query Point and All Training Points**
#
# - **Definition:** To find the nearest neighbors, you need to calculate the distance between the test (query) point and every point in the training set.
#
# - **Common Distance Metrics:**
#   - **Euclidean Distance:** The most common distance metric used for KNN.
#
#     \[
#     d(x, y) = \sqrt{ \sum_{i=1}^{n} (x_i - y_i)^2 }
#     \]
#
#     where \( x_i \) and \( y_i \) are the feature values of two data points \( x \) and \( y \), and \( n \) is the number of features.
#
#   - **Manhattan Distance:** Also called "taxicab" distance, it's the sum of the absolute differences of their coordinates:
#
#     \[
#     d(x, y) = \sum_{i=1}^{n} |x_i - y_i|
#     \]
#
#   - **Minkowski Distance:** A generalization of both Euclidean and Manhattan distances:
#
#     \[
#     d(x, y) = \left( \sum_{i=1}^{n} |x_i - y_i|^p \right)^{1/p}
#     \]
#
#     where \( p \) is a parameter that can be tuned (when \( p = 2 \), it becomes Euclidean distance, and \( p = 1 \) becomes Manhattan distance).
#
#   - **Cosine Similarity:** Used particularly in text classification or when the magnitude of vectors is less important than their direction (i.e., angle between them).
#
# - **Distance Calculation:** Once the distance metric is chosen, calculate the distance between the test point and each point in the training set.
#
# ---
#
#  3. **Identify the K Nearest Neighbors**
#
# - **Definition:** After calculating the distance between the query point and all training points, the next step is to **select the K nearest neighbors**. These are the K points that are closest to the query point based on the distance metric.
#
# - **How to find nearest neighbors:**
#   - Sort all training points based on their distance to the query point.
#   - Select the top K training points with the smallest distance.
#
# ---
#
#  4. **Make a Prediction Based on the Nearest Neighbors**
#
# - **For Classification:**
#   - The prediction is based on the **majority vote** among the K nearest neighbors.
#   - **Majority Voting Process:**
#     - For each of the K nearest neighbors, determine the class label.
#     - Assign the class label that appears most frequently among the K neighbors to the query point.
#
#     **Example:** If K = 5, and the 5 nearest neighbors are classified as [A, A, B, A, A], the predicted class label for the query point will be **A** (since it appears 4 times).
#
# - **For Regression:**
#   - The prediction is the **average** (or weighted average) of the target values of the K nearest neighbors.
#   - **Averaging Process:**
#     - Calculate the average of the values of the K nearest neighbors to predict the value for the query point.
#
#     **Example:** If K = 3 and the target values of the nearest neighbors are [10, 12, 15], the predicted value will be:
#
#     \[
#     \text{Predicted Value} = \frac{10 + 12 + 15}{3} = 12.33
#     \]
#
#   - **Weighted Average:** Optionally, a weighted average can be used, where closer neighbors have more influence on the prediction. This is often done by assigning a weight inversely proportional to the distance.
#
# ---
#
#  5. **Handle Ties (in Classification)**
#
# - **Tie in Majority Voting:** If there is a tie in the number of nearest neighbors from different classes, there are various strategies to break the tie:
#   - **Increase K:** One simple method is to increase K by 1, which may help to resolve ties.
#   - **Weighted Voting:** Instead of a simple majority vote, use a **distance-weighted voting** mechanism where closer neighbors have a higher voting weight.
#   - **Random Selection:** In cases where there's still a tie, some systems will choose the class randomly from the tied classes.
#
# ---
#
#  6. **Return the Prediction**
#
# - After identifying the K nearest neighbors and applying the appropriate rule (majority vote for classification or average for regression), the algorithm returns the predicted class label (for classification) or continuous value (for regression) for the query point.
#
# ---
#
#  Example Workflow of KNN
#
# 1. **Choose K:** Suppose K = 3.
# 2. **Calculate Distances:** Calculate the distance from the query point to all training points using Euclidean distance.
# 3. **Find K Nearest Neighbors:** Sort all training points by distance, and select the 3 nearest neighbors.
# 4. **Make Prediction:**
#    - **For Classification:** Suppose the classes of the 3 nearest neighbors are [A, A, B]. The predicted class will be **A** (since it has 2 votes).
#    - **For Regression:** Suppose the target values of the 3 nearest neighbors are [5, 7, 6]. The predicted value will be the average: \( \frac{5 + 7 + 6}{3} = 6 \).
# 5. **Return Prediction:** The algorithm outputs the predicted class (for classification) or value (for regression).
#
# ---
#
#  Additional Considerations
#
# - **Normalization/Standardization:** Since KNN relies on distance calculations, it's crucial to normalize or standardize the feature values, especially when features have different units (e.g., height in centimeters and weight in kilograms). This ensures that features contribute equally to the distance computation.
#
# - **Curse of Dimensionality:** As the number of features (dimensions) increases, the notion of "nearness" becomes less meaningful. This can degrade the performance of KNN, making dimensionality reduction techniques (like PCA) useful in high-dimensional spaces.
#
# ---
#
#  Summary of KNN Methodology:
#
# 1. **Choose K**, the number of neighbors to consider.
# 2. **Calculate distances** between the query point and all training points.
# 3. **Identify the K nearest neighbors** based on the calculated distances.
# 4. **Make a prediction** using majority voting (for classification) or averaging (for regression).
# 5. **Return the prediction** for the query point.
#
# The algorithm is simple, easy to understand, and effective for many classification and regression problems, particularly when the relationship between the data points is intuitive and not overly complex. However, it can become computationally expensive as the size of the dataset grows.

# %% [markdown]
# ## Breast Cancer Dataset

# %%
from sklearn.impute import SimpleImputer
import pandas as pd
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
cancer = pd.read_csv("./Cases/Wisconsin/BreastCancer.csv", index_col=0)
cancer.head()
# Out:
#         Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# Code
# 61634       5             4              3        1       2      2
# 63375       9             1              2        6       4     10
# 76389      10             4              7        2       2      8
# 95719       6            10             10       10       8     10
# 128059      1             1              1        1       2      5
#
#         BChromatin  NoemN  Mitoses      Class
# Code
# 61634            2      3        1     Benign
# 63375            7      7        2  Malignant
# 76389            6      1        1  Malignant
# 95719            7     10        7  Malignant
# 128059           5      1        1     Benign

# %%
X = cancer.drop("Class", axis=1)
y = cancer['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0      Benign  Malignant
# Class
# Benign        133          4
# Malignant       1         72

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9761904761904762

# %%
X = cancer.drop("Class", axis=1)
y = cancer['Class']
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})
# Out:
# for nearest neighbour 1, accuracy : 0.9761904761904762
# for nearest neighbour 2, accuracy : 0.9476190476190476
# for nearest neighbour 3, accuracy : 0.9761904761904762
# for nearest neighbour 4, accuracy : 0.9761904761904762
# for nearest neighbour 5, accuracy : 0.9904761904761905
# for nearest neighbour 6, accuracy : 0.9857142857142858
# for nearest neighbour 7, accuracy : 0.9857142857142858
# for nearest neighbour 8, accuracy : 0.9904761904761905
# for nearest neighbour 9, accuracy : 0.9857142857142858
# for nearest neighbour 10, accuracy : 0.9857142857142858

# %%
df = pd.DataFrame(data=accuracy)
df = df.sort_values(by='accuracy', ascending=False)
df.head(1)
# Out:
#    NN  accuracy
# 4   5  0.990476

# %% [markdown]
# ## Company Bankruptcy dataset

# %%
brupt = pd.read_csv("./Cases/Company Bankruptcy/data.csv")
brupt.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
X = brupt.drop('Bankrupt?', axis=1)
y = brupt['Bankrupt?']
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24, stratify=brupt['Bankrupt?'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})
# Out:
# for nearest neighbour 1, accuracy : 0.9437927663734116
# for nearest neighbour 2, accuracy : 0.9672531769305963
# for nearest neighbour 3, accuracy : 0.9623655913978495
# for nearest neighbour 4, accuracy : 0.9652981427174976
# for nearest neighbour 5, accuracy : 0.966275659824047
# for nearest neighbour 6, accuracy : 0.967741935483871
# for nearest neighbour 7, accuracy : 0.9672531769305963
# for nearest neighbour 8, accuracy : 0.967741935483871
# for nearest neighbour 9, accuracy : 0.967741935483871
# for nearest neighbour 10, accuracy : 0.967741935483871

# %%
bank_df = pd.DataFrame(data=accuracy)
bank_df = bank_df.sort_values(by='accuracy', ascending=False)
bank_df.head(1)
# Out:
#    NN  accuracy
# 5   6  0.967742

# %%
brupt['Bankrupt?'].value_counts()
# Out:
# Bankrupt?
# 0    6599
# 1     220
# Name: count, dtype: int64

# %% [markdown]
# ## HR Analytics dataset

# %%
hr_df = pd.read_csv("./Cases/human-resources-analytics/HR_comma_sep.csv")
hr_df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.10             0.77               6                   247
# 3                0.92             0.85               5                   259
# 4                0.89             1.00               5                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   5              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
hr_df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.10             0.77               6                   247
# 3                0.92             0.85               5                   259
# 4                0.89             1.00               5                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   5              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
X = hr_df.drop('left', axis=1)
X_ohe = pd.get_dummies(X, drop_first=True)
y = hr_df['left']
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X_ohe, y, test_size=0.3, random_state=24, stratify=hr_df['left'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})
# Out:
# for nearest neighbour 1, accuracy : 0.948877528339631
# for nearest neighbour 2, accuracy : 0.9502111580351189
# for nearest neighbour 3, accuracy : 0.9442098244054234
# for nearest neighbour 4, accuracy : 0.9442098244054234
# for nearest neighbour 5, accuracy : 0.933763058457435
# for nearest neighbour 6, accuracy : 0.9417648366303623
# for nearest neighbour 7, accuracy : 0.9359857746165815
# for nearest neighbour 8, accuracy : 0.938208490775728
# for nearest neighbour 9, accuracy : 0.938208490775728
# for nearest neighbour 10, accuracy : 0.9426539230940209

# %%
hr = pd.DataFrame(data=accuracy)
hr = hr.sort_values(by='accuracy', ascending=False)
hr.head(1)
# Out:
#    NN  accuracy
# 1   2  0.950211

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=['Not Left','Left'])
disp.plot()
plt.show()

# %% [markdown]
# **Recall Score** : Proportion of correctly predicted among actual labels

# %%
from sklearn.metrics import recall_score
print(recall_score(y_test, y_pred, pos_label=1))        #Left
print(recall_score(y_test, y_pred, pos_label=0))        #Not Left
# Out:
# 0.9112149532710281
# 0.952464275298921

# %% [markdown]
# **Precision Score** : Proportion of correctly predicted among predicted labels

# %%
from sklearn.metrics import precision_score
print(precision_score(y_test, y_pred, pos_label=1)) 
print(precision_score(y_test, y_pred, pos_label=0))
# Out:
# 0.8567662565905096
# 0.9717346027967867

# %% [markdown]
# **f1_score** It is the harmonic mean of precision and recall

# %%
from sklearn.metrics import f1_score
print(f1_score(y_test, y_pred, pos_label=1)) 
print(f1_score(y_test, y_pred, pos_label=0))
# Out:
# 0.8831521739130435
# 0.9620029455081002

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      3429
#            1       0.86      0.91      0.88      1070
#
#     accuracy                           0.94      4499
#    macro avg       0.91      0.93      0.92      4499
# weighted avg       0.94      0.94      0.94      4499

# %%
y_test.value_counts()
# Out:
# left
# 0    3429
# 1    1070
# Name: count, dtype: int64

# %% [markdown]
# Best n_value with criterion of F1-score (left)

# %%
X = hr_df.drop('left', axis=1)
X_ohe = pd.get_dummies(X, drop_first=True)
y = hr_df['left']
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X_ohe, y, test_size=0.3, random_state=24, stratify=hr_df['left'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    # print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'f1_score': f1_score(y_test, y_pred , pos_label=1)})

# %%
y.value_counts()
# Out:
# left
# 0    11428
# 1     3567
# Name: count, dtype: int64

# %%
hr = pd.DataFrame(data=accuracy)
hr = hr.sort_values(by='f1_score', ascending=False)
hr.head(5)
# Out:
#    NN  f1_score
# 0   1  0.896953
# 1   2  0.893738
# 2   3  0.887696
# 3   4  0.883635
# 9  10  0.883152

# %% [markdown]
# ## Glass Dataset

# %%
glass = pd.read_csv("./Cases/Glass Identification/Glass.csv")
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed
# 1  building_windows_float_processed
# 2  building_windows_float_processed
# 3  building_windows_float_processed
# 4  building_windows_float_processed

# %%
glass['Type'].value_counts()
# Out:
# Type
# building_windows_non_float_processed    76
# building_windows_float_processed        70
# headlamps                               29
# vehicle_windows_float_processed         17
# containers                              13
# tableware                                9
# Name: count, dtype: int64

# %%
X = glass.drop('Type', axis=1)
y = glass['Type']
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24, stratify=glass['Type'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    # print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})

glass_df = pd.DataFrame(data=accuracy)
glass_df = glass_df.sort_values(by='accuracy', ascending=False)
glass_df.head(5)
# Out:
#    NN  accuracy
# 0   1  0.707692
# 1   2  0.646154
# 2   3  0.630769
# 3   4  0.630769
# 4   5  0.630769

# %% [markdown]
# ## Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
X = glass.drop('Type', axis=1)
y = glass['Type']
std_scl = StandardScaler().set_output(transform='pandas')
# std_scl.fit(X)              # Calculates mean and std dev of all the columns {only .fit()}
X_scaled = std_scl.fit_transform(X)
X_scaled
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=24, stratify=glass['Type'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    # print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})

glass_df = pd.DataFrame(data=accuracy)
glass_df = glass_df.sort_values(by='accuracy', ascending=False)
glass_df.head(5)
# Out:
#    NN  accuracy
# 2   3  0.676923
# 0   1  0.661538
# 6   7  0.661538
# 1   2  0.646154
# 3   4  0.646154

# %% [markdown]
# ## Image Segmentation Dataset

# %%
image_df = pd.read_csv("./Cases/Image Segmentation/Image_Segmentation.csv")
image_df.head()
# Out:
#        Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0  BRICKFACE                  188                  133                   9
# 1  BRICKFACE                  105                  139                   9
# 2  BRICKFACE                   34                  137                   9
# 3  BRICKFACE                   39                  111                   9
# 4  BRICKFACE                   16                  128                   9
#
#    short.line.density.5  short.line.density.2  vedge.mean  vegde.sd  \
# 0                   0.0                   0.0    0.333333  0.266667
# 1                   0.0                   0.0    0.277778  0.107407
# 2                   0.0                   0.0    0.500000  0.166667
# 3                   0.0                   0.0    0.722222  0.374074
# 4                   0.0                   0.0    0.500000  0.077778
#
#    hedge.mean  hedge.sd  intensity.mean  rawred.mean  rawblue.mean  \
# ...

# %%
X = image_df.drop('Class', axis=1)
y = image_df['Class']
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24, stratify=image_df['Class'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})

image_seg = pd.DataFrame(data=accuracy)
image_seg = image_seg.sort_values(by='accuracy', ascending=False)
image_seg.head(5)
# Out:
#    NN  accuracy
# 1   2  0.793651
# 3   4  0.777778
# 8   9  0.777778
# 4   5  0.761905
# 6   7  0.761905

# %% [markdown]
# # Scaling Unlabelled data

# %%
X_train = np.array([[1000,0.3],[200,0.9], [300,1.2], [400,3],[500,0.5],[600,0.6]])
X_train = pd.DataFrame(X_train, columns=['X1','X2'])
X_test = np.array([[2000,0.001],[100,0.1],[300,0.3],[200,3],[1000,3.2]])
X_test = pd.DataFrame(X_test, columns=['X1','X2'])

# %%
X_test
# Out:
#        X1     X2
# 0  2000.0  0.001
# 1   100.0  0.100
# 2   300.0  0.300
# 3   200.0  3.000
# 4  1000.0  3.200

# %%
scaler = MinMaxScaler().set_output(transform='pandas')
X_trn_scl = scaler.fit_transform(X_train)
X_trn_scl
# Out:
#       X1        X2
# 0  1.000  0.000000
# 1  0.000  0.222222
# 2  0.125  0.333333
# 3  0.250  1.000000
# 4  0.375  0.074074
# 5  0.500  0.111111

# %% [markdown]
# Never apply `.fit()` of scaling on X_test

# %%
scaler.transform(X_test)
# Out:
#       X1        X2
# 0  2.250 -0.110741
# 1 -0.125 -0.074074
# 2  0.125  0.000000
# 3  0.000  1.000000
# 4  1.000  1.074074

# %% [markdown]
# `.fit_transform()` should be done on the training data objects.
# `.transform()` should be done on testing data objects.

# %%
glass = pd.read_csv("./Cases/Glass Identification/Glass.csv")
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed
# 1  building_windows_float_processed
# 2  building_windows_float_processed
# 3  building_windows_float_processed
# 4  building_windows_float_processed

# %%
X = glass.drop('Type', axis=1)
y = glass['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24, stratify=glass['Type'])

# %%
scaler = MinMaxScaler()
X_trn_scl = scaler.fit_transform(X_train)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_trn_scl, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
X_tst_scl = scaler.transform(X_test)
y_pred = knn.predict(X_tst_scl)
accuracy_score(y_test, y_pred)
# Out:
# 0.7230769230769231

# %%
n_values = np.arange(1,11)
accuracy = []
for i in n_values:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24, stratify=glass['Type'])
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_trn_scl, y_train)
    y_pred = knn.predict(X_tst_scl)
    # print(f"for nearest neighbour {i}, accuracy : {accuracy_score(y_test, y_pred)}")
    accuracy.append({'NN':i, 'accuracy': accuracy_score(y_test, y_pred)})

glass_df = pd.DataFrame(data=accuracy)
glass_df = glass_df.sort_values(by='accuracy', ascending=False)
glass_df.head(5)
# Out:
#    NN  accuracy
# 2   3  0.723077
# 0   1  0.661538
# 1   2  0.646154
# 3   4  0.615385
# 4   5  0.600000

# %%
df = pd.read_csv('./Datasets/Boston.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import plotly.express as px
from io import BytesIO
import base64

def plot_auto(data_input):
    # Identify column types
    numeric_cols = data_input.select_dtypes(include=np.number).columns.tolist()
    date_cols = data_input.select_dtypes(include=[np.datetime64]).columns.tolist()
    categorical_cols = [col for col in data_input.columns if col not in numeric_cols + date_cols]

    images = []

    # 1. Bar Plot (Categorical data)
    if categorical_cols:
        cat_col = categorical_cols[0]
        plt.figure(figsize=(8, 6))
        sns.countplot(data=data_input, x=cat_col, palette="Set2")
        plt.title(f'Bar Plot for {cat_col}', fontsize=16)
        plt.xlabel(f'{cat_col} categories', fontsize=12)
        plt.ylabel('Count', fontsize=12)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    # 2. Horizontal Bar Plot (Categorical data)
    if categorical_cols:
        cat_col = categorical_cols[0]
        plt.figure(figsize=(8, 6))
        sns.countplot(data=data_input, y=cat_col, palette="Set2")
        plt.title(f'Horizontal Bar Plot for {cat_col}', fontsize=16)
        plt.xlabel('Count', fontsize=12)
        plt.ylabel(f'{cat_col} categories', fontsize=12)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    # 3. Line Plot (Numerical vs. Date)
    if numeric_cols and date_cols:
        plt.figure(figsize=(10, 6))
        sns.lineplot(x=data_input[date_cols[0]], y=data_input[numeric_cols[0]], palette="viridis")
        plt.title(f'Line Plot: {numeric_cols[0]} vs {date_cols[0]}', fontsize=16)
        plt.xlabel(f'{date_cols[0]}', fontsize=12)
        plt.ylabel(f'{numeric_cols[0]}', fontsize=12)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    # 4. Scatter Plot (Numeric x Numeric)
    if len(numeric_cols) >= 2:
        plt.figure(figsize=(8, 6))
        sns.scatterplot(data=data_input, x=numeric_cols[0], y=numeric_cols[1], color="purple")
        plt.title(f'Scatter Plot: {numeric_cols[0]} vs {numeric_cols[1]}', fontsize=16)
        plt.xlabel(f'{numeric_cols[0]}', fontsize=12)
        plt.ylabel(f'{numeric_cols[1]}', fontsize=12)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    # 5. Pie Chart (Categorical data)
    if categorical_cols:
        cat_col = categorical_cols[0]
        pie_data = data_input[cat_col].value_counts()
        plt.figure(figsize=(8, 8))
        plt.pie(pie_data, labels=pie_data.index, autopct='%1.1f%%', colors=sns.color_palette("Set2", len(pie_data)))
        plt.title(f'Pie Chart for {cat_col}', fontsize=16)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    # 6. Histogram (Numeric data)
    if numeric_cols:
        plt.figure(figsize=(8, 6))
        sns.histplot(data_input[numeric_cols[0]], kde=True, color="skyblue")
        plt.title(f'Histogram for {numeric_cols[0]}', fontsize=16)
        plt.xlabel(f'{numeric_cols[0]}', fontsize=12)
        plt.ylabel('Frequency', fontsize=12)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    # 7. Bubble Chart (Numeric x Numeric x Size)
    if len(numeric_cols) >= 3:
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=data_input, x=numeric_cols[0], y=numeric_cols[1], size=numeric_cols[2], sizes=(20, 200), legend=False, color="blue")
        plt.title(f'Bubble Chart: {numeric_cols[0]} vs {numeric_cols[1]} (size: {numeric_cols[2]})', fontsize=16)
        plt.xlabel(f'{numeric_cols[0]}', fontsize=12)
        plt.ylabel(f'{numeric_cols[1]}', fontsize=12)
        plt.tight_layout()
        img_buf = BytesIO()
        plt.savefig(img_buf, format='png')
        img_buf.seek(0)
        images.append(base64.b64encode(img_buf.read()).decode('utf-8'))
        plt.close()

    return images

# Example Usage:
# data_input = pd.read_csv('your_data.csv')
images = plot_auto(df)

# %%
from IPython.display import display, HTML
import base64

def display_images(image_list):
    html_code = ""
    
    for image in image_list:
        html_code += f'<img src="data:image/png;base64,{image}" style="width: 500px; margin: 10px;">'
    
    display(HTML(html_code))

# Assuming 'images' is the list of base64-encoded image strings from plot_auto()
display_images(images)
# Out:
# <img src="data:image/png;base64,..." style="width: 500px; margin: 10px;"><img src="data:image/png;base64,..." style="width: 500px; margin: 10px;"><img src="data:image/png;base64,..." style="width: 500px; margin: 10px;">
