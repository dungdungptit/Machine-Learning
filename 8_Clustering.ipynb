# %% [markdown]
# # Hierachical Clustering

# %% [markdown]
# ## AgglomerativeClustering

# %% [markdown]
# **Unsupervised Learning** là một loại học máy (machine learning) trong đó thuật toán không được cung cấp nhãn (labels) cho dữ liệu huấn luyện. Mục tiêu của unsupervised learning là tìm ra cấu trúc ẩn hoặc các mối quan hệ trong dữ liệu mà không cần sự can thiệp từ bên ngoài. Một trong những ứng dụng phổ biến của unsupervised learning là **Clustering Analysis** (Phân cụm phân tích), nơi thuật toán nhóm các đối tượng tương tự vào cùng một nhóm (cluster) mà không cần thông tin về nhãn.
#  1. **Clustering Analysis là gì?**
# Clustering Analysis là một kỹ thuật phân nhóm dữ liệu vào các nhóm hoặc cụm sao cho các đối tượng trong cùng một nhóm có sự tương đồng cao và khác biệt với các đối tượng ở nhóm khác. Đây là một phương pháp phân tích dữ liệu cơ bản trong unsupervised learning, giúp phát hiện ra các mẫu hoặc cấu trúc tiềm ẩn trong dữ liệu.
#  2. **Các thuật toán Clustering phổ biến**
# Một số thuật toán clustering phổ biến bao gồm:
#
# - **K-means clustering**
#     - **Mô tả**: K-means là một trong những thuật toán phân cụm đơn giản và phổ biến nhất. Thuật toán này chia dữ liệu thành **K nhóm** (clusters), trong đó **K** là một tham số được xác định trước. Mỗi nhóm sẽ có một trung tâm (centroid) và thuật toán sẽ tối ưu sao cho các điểm trong cùng một nhóm gần với trung tâm của nhóm đó nhất.
#     - **Quy trình**:
#         1. Chọn **K** cụm ngẫu nhiên.
#         2. Gán mỗi điểm dữ liệu vào cụm gần nhất (dựa trên khoảng cách đến trung tâm).
#         3. Cập nhật lại vị trí của các trung tâm cụm.
#         4. Lặp lại quá trình này cho đến khi không có sự thay đổi về vị trí trung tâm.
#     - **Ưu điểm**: Đơn giản và nhanh chóng, dễ hiểu.
#     - **Nhược điểm**: Cần biết trước số lượng cụm (K), không phù hợp với dữ liệu có cấu trúc phức tạp.
#
# - **Hierarchical Clustering**
#     - **Mô tả**: Thuật toán phân cụm phân cấp tạo ra một cây phân cấp (dendrogram), giúp nhóm các điểm dữ liệu theo cách phân chia từ trên xuống dưới (agglomerative) hoặc từ dưới lên trên (divisive).
#     - **Quy trình**:
#         1. Mỗi điểm dữ liệu bắt đầu là một cụm riêng biệt.
#         2. Các cụm được hợp nhất lại (hoặc chia ra) dựa trên một tiêu chí tương tự (ví dụ: khoảng cách Euclid).
#         3. Tiếp tục cho đến khi đạt được một số lượng cụm mong muốn.
#     - **Ưu điểm**: Không cần biết trước số lượng cụm, cung cấp cái nhìn sâu sắc về mối quan hệ giữa các cụm.
#     - **Nhược điểm**: Tốn kém tính toán cho các bộ dữ liệu lớn.
#
# - **DBSCAN (Density-Based Spatial Clustering of Applications with Noise)**
#     - **Mô tả**: DBSCAN là một thuật toán phân cụm dựa trên mật độ. Nó phân nhóm các điểm có mật độ cao và coi các điểm có mật độ thấp là "nhiễu" (outliers).
#     - **Quy trình**:
#         1. Bắt đầu với một điểm dữ liệu và tìm các điểm trong một bán kính nhất định (epsilon).
#         2. Nếu số lượng điểm trong bán kính lớn hơn một ngưỡng tối thiểu (minPts), các điểm này sẽ được nhóm vào một cụm.
#         3. Các điểm ngoài cụm hoặc không đủ điểm trong bán kính sẽ được coi là nhiễu.
#     - **Ưu điểm**: Không cần biết trước số lượng cụm, có thể phát hiện các cụm có hình dạng bất kỳ, xử lý tốt với nhiễu.
#     - **Nhược điểm**: Cần chọn các tham số epsilon và minPts hợp lý, không hiệu quả với các dữ liệu có mật độ thay đổi.
#
# - **Gaussian Mixture Models (GMM)**
#     - **Mô tả**: GMM là một mô hình thống kê sử dụng hỗn hợp các phân phối Gaussian (phân phối chuẩn) để mô phỏng các cụm. Mỗi cụm được xem như là một phân phối Gaussian, và thuật toán sẽ tìm các tham số của các phân phối này.
#     - **Ưu điểm**: Linh hoạt hơn K-means, có thể mô phỏng các cụm có hình dạng khác nhau.
#     - **Nhược điểm**: Đòi hỏi một số lượng tham số lớn, yêu cầu tính toán phức tạp.
#  3. **Đánh giá chất lượng của Clustering**
# Đánh giá chất lượng của các cụm có thể khó khăn vì không có nhãn sẵn có. Tuy nhiên, một số phương pháp đánh giá chất lượng phân cụm bao gồm:
#
# - **Silhouette Score**: Đo lường mức độ tương đồng của các đối tượng trong cùng một cụm và mức độ khác biệt với các đối tượng trong cụm khác. Giá trị dao động từ -1 (xấu) đến 1 (tốt).
#
# - **Inertia (cho K-means)**: Đo lường tổng bình phương khoảng cách giữa các điểm trong cụm và trung tâm của nó. Giá trị nhỏ hơn thường chỉ ra rằng các cụm phân tách tốt hơn.
#
# - **Davies-Bouldin Index**: Một chỉ số khác đo lường sự tách biệt giữa các cụm. Giá trị nhỏ hơn cho thấy cụm phân tách tốt hơn.
#  4. **Ứng dụng của Clustering**
# Clustering có rất nhiều ứng dụng thực tế trong nhiều lĩnh vực:
#
# - **Phân nhóm khách hàng**: Phân nhóm khách hàng thành các nhóm tương tự để tối ưu hóa chiến lược marketing.
# - **Phân tích văn bản**: Phân nhóm các tài liệu văn bản dựa trên nội dung của chúng (ví dụ: phân loại bài viết báo chí).
# - **Phát hiện gian lận**: Nhóm các giao dịch có mô hình tương tự để phát hiện hành vi gian lận.
# - **Sinh học**: Nhóm các gene hoặc protein có chức năng tương tự.
#    5. **Tóm tắt**
# Clustering Analysis là một phương pháp mạnh mẽ trong unsupervised learning để phát hiện cấu trúc ẩn trong dữ liệu. Các thuật toán phổ biến như K-means, DBSCAN, và hierarchical clustering có thể được sử dụng tùy thuộc vào bản chất và yêu cầu của bài toán. Quá trình phân cụm giúp chúng ta hiểu rõ hơn về dữ liệu và đưa ra các quyết định hoặc chiến lược phù hợp.

# %% [markdown]
# [ielts-writing-buddy](https://github.com/nhanluongoe/ielts-writing-buddy?tab=readme-ov-file)
#
# [IELTS_PracticeAndEvaluation](https://github.com/ZainabZaman/IELTS_PracticeAndEvaluation/tree/main)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram, linkage
import seaborn as sns
import pandas as pd
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("./Datasets/simp_clust.csv")
df.head()
# Out:
#   Name  X1   X2
# 0    A  23  150
# 1    B  24  167
# 2    C  67  256
# 3    D  65  240
# 4    E  12  102

# %%
# Áp dụng Agglomerative Clustering
agg_clust = AgglomerativeClustering(n_clusters=3, linkage='average')
df['Cluster'] = agg_clust.fit_predict(df[['X1', 'X2']])

# %%
# Vẽ biểu đồ phân cụm bằng Seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='X1', y='X2', hue='Cluster', palette='Set2', s=100, style='Cluster', markers=["o", "s"])

# Thêm tên vào mỗi điểm dữ liệu
for i in range(df.shape[0]):
    plt.text(df['X1'][i] + 1, df['X2'][i] + 1, df['Name'][i], horizontalalignment='left', size='medium')

plt.title('Agglomerative Clustering with Seaborn')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_7852\2788593276.py:3: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=df, x='X1', y='X2', hue='Cluster', palette='Set2', s=100, style='Cluster', markers=["o", "s"])

# %%
# Lấy các cột X1 và X2 làm dữ liệu phân cụm
X = df[['X1', 'X2']].values

# Tính toán ma trận khoảng cách với phương pháp 'ward'
linked = linkage(X, method='ward')

# Vẽ dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked, labels=df['Name'].to_numpy(), orientation='top')

# Thêm tiêu đề và nhãn
plt.title('Dendrogram for Agglomerative Clustering')
plt.xlabel('Data points')
plt.ylabel('Distance')
plt.show()

# %%
# Áp dụng PCA để giảm chiều về 2D (mặc dù dữ liệu này có 2 chiều nhưng đây là bước chuẩn bị)
pca = PCA().set_output(transform='pandas')
X_pca = pca.fit_transform(X)

# %%
# Áp dụng Agglomerative Clustering sau khi giảm chiều dữ liệu
agg_clust = AgglomerativeClustering(n_clusters=3, linkage='average')
df['Cluster'] = agg_clust.fit_predict(X_pca)

# %%
X_pca
# Out:
#           pca0       pca1
# 0   -31.673724  -5.469123
# 1   -15.565306 -10.993513
# 2    83.094542  -4.974019
# 3    67.531972  -0.754256
# 4   -80.258384   2.563982
# 5   -86.189196   3.915084
# 6   -69.867846   1.545795
# 7   -82.867638   1.472288
# 8   -21.949014   2.432144
# 9   -35.541129  -1.721700
# 10   63.877499   6.148267
# 11   88.951847   6.674671
# 12  120.456377  -0.839619

# %%
# Vẽ biểu đồ phân cụm bằng Seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca['pca0'], y=X_pca['pca1'], hue=df['Cluster'], palette='Set2', s=100, style=df['Cluster'], markers=["o", "s"])
# Out:
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_7852\3354386464.py:3: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x=X_pca['pca0'], y=X_pca['pca1'], hue=df['Cluster'], palette='Set2', s=100, style=df['Cluster'], markers=["o", "s"])
# <Axes: xlabel='pca0', ylabel='pca1'>

# %%
# Thêm tên vào mỗi điểm dữ liệu
for i in range(X_pca.shape[0]):
    plt.text(X_pca['pca0'][i] + 1, X_pca['pca1'][i] + 1, df['Name'][i], horizontalalignment='left', size='medium')

# Tiêu đề và nhãn
plt.title('PCA and Agglomerative Clustering with Names')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backends\backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backends\backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\anaconda3\envs\dung\lib\site-packages\matplotlib\backends\backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 102528x6564 pixels is too large. It must be less than 2^16 in each direction.

# %%
X_pca.shape
# Out:
# (13, 2)

# %%
df.shape
# Out:
# (13, 4)

# %% [markdown]
# ### Nutrient

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA   
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, silhouette_score

# %%
df = pd.read_csv("./Datasets/nutrient.csv", index_col=0)
df.head()
# Out:
#               energy  protein  fat  calcium  iron
# Food_Item
# BEEF BRAISED     340       20   28        9   2.6
# HAMBURGER        245       21   17        9   2.7
# BEEF ROAST       420       15   39        7   2.0
# BEEF STEAK       375       19   32        9   2.6
# BEEF CANNED      180       22   10       17   3.7

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaled_data = scaler.fit_transform(df)
scaled_data.head()
prcomp = PCA().set_output(transform='pandas')
pca_data = prcomp.fit_transform(scaled_data)

# %%
Ks = [2,3,4,5,6,7]
scores = []
for i in Ks:
    clust = AgglomerativeClustering(n_clusters=i, linkage='average')
    clust.fit(scaled_data)
    scores.append(silhouette_score(scaled_data, clust.labels_))
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])
# Out:
# Best no. of clusters: 3
# Best Scores: 0.44531853755129397

# %% [markdown]
# ## K-means

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA   
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, f1_score, silhouette_score
from tqdm import tqdm
import os
from pca import pca
os.chdir("./Datasets/")

# %%
df = pd.read_csv("milk.csv", index_col=0)
df.head()
# Out:
#            water  protein  fat  lactose   ash
# Animal
# HORSE       90.1      2.6  1.0      6.9  0.35
# ORANGUTAN   88.5      1.4  3.5      6.0  0.24
# MONKEY      88.4      2.2  2.7      6.4  0.18
# DONKEY      90.3      1.7  1.4      6.2  0.40
# HIPPO       90.4      0.6  4.5      4.4  0.10

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaled_data = scaler.fit_transform(df)
scaled_data.head()
# Out:
#               water   protein       fat   lactose       ash
# Animal
# HORSE      0.948806 -1.009291 -0.903208  1.542217 -1.037554
# ORANGUTAN  0.821407 -1.344603 -0.660619  1.040773 -1.259945
# MONKEY     0.813445 -1.121062 -0.738247  1.263637 -1.381249
# DONKEY     0.964731 -1.260775 -0.864394  1.152205 -0.936467
# HIPPO      0.972694 -1.568145 -0.563583  0.149319 -1.542988

# %%
km = KMeans(n_clusters=5)
km.fit(scaled_data)
km.labels_
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 2, 0, 2, 0, 0, 2, 3, 4, 4, 4,
#        4, 1, 1])

# %%
Ks = [2,3,4,5,6,7]
scores = []
for i in Ks:
    clust = KMeans(n_clusters=i)
    clust.fit(scaled_data)
    scores.append(silhouette_score(scaled_data, clust.labels_))
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])
# Out:
# Best no. of clusters: 2
# Best Scores: 0.5258508931703421

# %% [markdown]
# ### rfm

# %%
rfm = pd.read_csv("../Cases/Recency Frequency Monetary/rfm_data_customer.csv", index_col=0)

# %%
rfm.head()
# Out:
#              revenue most_recent_visit  number_of_orders  recency_days
# customer_id
# 22086            777        2006-05-14                 9           232
# 2290            1555        2006-09-08                16           115
# 26377            336        2006-11-19                 5            43
# 24650           1189        2006-10-29                12            64
# 12883           1229        2006-12-09                12            23

# %%
rfm = rfm.drop("most_recent_visit", axis=1)
rfm.head()
# Out:
#              revenue  number_of_orders  recency_days
# customer_id
# 22086            777                 9           232
# 2290            1555                16           115
# 26377            336                 5            43
# 24650           1189                12            64
# 12883           1229                12            23

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaled_data = scaler.fit_transform(rfm)
scaled_data.head()
# Out:
#               revenue  number_of_orders  recency_days
# customer_id
# 22086       -0.464600         -0.265676      0.385878
# 2290         1.774110          1.972752     -0.506581
# 26377       -1.733586         -1.544778     -1.055787
# 24650        0.720938          0.693650     -0.895602
# 12883        0.836039          0.693650     -1.208344

# %%
km = KMeans(n_clusters=5)
km.fit(scaled_data)
km.labels_
# Out:
# array([3, 0, 3, ..., 2, 3, 0])

# %%
Ks = [2,3,4,5,6,7]
scores = []
for i in tqdm(range(len(Ks))):
    clust = KMeans(n_clusters=Ks[i])
    clust.fit(scaled_data)
    scores.append(silhouette_score(scaled_data, clust.labels_))
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])
# Out:
# 100%|██████████| 6/6 [02:26<00:00, 24.47s/it]
# Best no. of clusters: 3
# Best Scores: 0.37096182414232104

# %%
clust = KMeans(n_clusters=Ks[imax])
clust.fit(scaled_data)
# Out:
# KMeans(n_clusters=3)

# %%
clust.labels_
# Out:
# array([1, 2, 1, ..., 1, 1, 2])

# %%
df_clust = rfm.copy()
df_clust['Clust'] = clust.labels_
df_clust['Clust'] = df_clust['Clust'].astype(str)

# %%
df_clust.groupby('Clust').mean()
# Out:
#            revenue  number_of_orders  recency_days
# Clust
# 0       692.339108          7.351461    416.089786
# 1       751.008738          8.244067    135.885383
# 2      1283.175967         12.926186    133.255516

# %% [markdown]
# ### milk

# %%
milk = pd.read_csv("./milk.csv", index_col=0)
milk.head()
# Out:
#            water  protein  fat  lactose   ash
# Animal
# HORSE       90.1      2.6  1.0      6.9  0.35
# ORANGUTAN   88.5      1.4  3.5      6.0  0.24
# MONKEY      88.4      2.2  2.7      6.4  0.18
# DONKEY      90.3      1.7  1.4      6.2  0.40
# HIPPO       90.4      0.6  4.5      4.4  0.10

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaled_data = scaler.fit_transform(milk)
scaled_data.head()
# Out:
#               water   protein       fat   lactose       ash
# Animal
# HORSE      0.948806 -1.009291 -0.903208  1.542217 -1.037554
# ORANGUTAN  0.821407 -1.344603 -0.660619  1.040773 -1.259945
# MONKEY     0.813445 -1.121062 -0.738247  1.263637 -1.381249
# DONKEY     0.964731 -1.260775 -0.864394  1.152205 -0.936467
# HIPPO      0.972694 -1.568145 -0.563583  0.149319 -1.542988

# %%
prcomp = PCA().set_output(transform='pandas')
pca_data = prcomp.fit_transform(scaled_data)

# %%
model = pca()
result = model.fit_transform(scaled_data, col_labels=milk.columns, row_labels = list(milk.index))
# Out:
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [5] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [2] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [5] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %%
components = pca_data
model.biplot(label=True, legend=True)
for i in np.arange(0, milk.shape[0]):
    plt.text(components.values[i, 0] + 0.1, components.values[i, 1] + 0.1, list(milk.index)[i])

plt.show()
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.

# %%
km = KMeans(n_clusters=4, random_state=24)
km.fit(scaled_data)
km.inertia_
# Out:
# 18.493970123821068

# %%
Ks = np.arange(2,25)
wss = []
for i in Ks:
    km = KMeans(n_clusters=i)
    km.fit(scaled_data)
    wss.append(km.inertia_)
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])
# Out:
# Best no. of clusters: 3
# Best Scores: 0.37096182414232104

# %%
plt.scatter(Ks, wss, c='red')
plt.plot(Ks, wss)
plt.ylabel("Ks")
plt.xlabel("wss")
plt.title("Scree plot")
plt.show()

# %% [markdown]
# ### NOTE: Elbow Point
#
# Elbow Method: The point at which
# Elbow is observed, the cluster no, coresponding ro that elbow can be considered inertia extremely reduce
# => no. of clusters is optimized
#
# In the picture above, elbow is k=5

# %% [markdown]
# ### Nutrient

# %%
USArrests = pd.read_csv("./USArrests.csv", index_col=0)
USArrests.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaled_data = scaler.fit_transform(USArrests)
scaled_data.head()
# Out:
#               Murder   Assault  UrbanPop      Rape
# Alabama     1.255179  0.790787 -0.526195 -0.003451
# Alaska      0.513019  1.118060 -1.224067  2.509424
# Arizona     0.072361  1.493817  1.009122  1.053466
# Arkansas    0.234708  0.233212 -1.084492 -0.186794
# California  0.281093  1.275635  1.776781  2.088814

# %%
prcomp = PCA().set_output(transform='pandas')
pca_data = prcomp.fit_transform(scaled_data)

# %%
Ks = [2,3,4,5,6,7]
scores = []
for i in tqdm(range(len(Ks))):
    clust = KMeans(n_clusters=Ks[i])
    clust.fit(scaled_data)
    scores.append(silhouette_score(scaled_data, clust.labels_))
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 98.42it/s]
# Best no. of clusters: 2
# Best Scores: 0.4084890326217641

# %%
components = pca_data
model.biplot(label=True, legend=True)
for i in np.arange(0, USArrests.shape[0]):
    plt.text(components.values[i, 0], components.values[i, 1], list(USArrests.index)[i])

plt.show()
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.

# %%
Ks = np.arange(2,25)
wss = []
for i in Ks:
    km = KMeans(n_clusters=i)
    km.fit(scaled_data)
    wss.append(km.inertia_)
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])

plt.scatter(Ks, wss, c='red')
plt.plot(Ks, wss)
plt.ylabel("Ks")
plt.xlabel("wss")
plt.title("Scree plot")
plt.show()
# Out:
# Best no. of clusters: 2
# Best Scores: 0.4084890326217641

# %% [markdown]
# ### Iris

# %%
iris = pd.read_csv("./iris.csv", index_col=-1)
iris.head()
# Out:
#          Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa            5.1          3.5           1.4          0.2
# setosa            4.9          3.0           1.4          0.2
# setosa            4.7          3.2           1.3          0.2
# setosa            4.6          3.1           1.5          0.2
# setosa            5.0          3.6           1.4          0.2

# %%
scaler = StandardScaler().set_output(transform='pandas')
scaled_data = scaler.fit_transform(iris)
scaled_data.head()
prcomp = PCA().set_output(transform='pandas')
pca_data = prcomp.fit_transform(scaled_data)
Ks = [2,3,4,5,6,7]
scores = []
for i in tqdm(range(len(Ks))):
    clust = KMeans(n_clusters=Ks[i])
    clust.fit(scaled_data)
    scores.append(silhouette_score(scaled_data, clust.labels_))
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])
components = pca_data
model.biplot(label=True, legend=True)
for i in np.arange(0, iris.shape[0]):
    plt.text(components.values[i, 0], components.values[i, 1], list(iris.index)[i])

plt.show()
Ks = np.arange(2,25)
wss = []
for i in Ks:
    km = KMeans(n_clusters=i)
    km.fit(scaled_data)
    wss.append(km.inertia_)
    
imax = np.argmax(scores)
print("Best no. of clusters:", Ks[imax])
print("Best Scores:", scores[imax])

plt.scatter(Ks, wss, c='red')
plt.plot(Ks, wss)
plt.ylabel("Ks")
plt.xlabel("wss")
plt.title("Scree plot")
plt.show()
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 90.97it/s]
# [scatterd] >INFO> Create scatterplot
# Best no. of clusters: 2
# Best Scores: 0.5817500491982808
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.
# Best no. of clusters: 2
# Best Scores: 0.5817500491982808
